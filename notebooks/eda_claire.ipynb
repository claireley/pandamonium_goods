# %%
import pandas as pd
import yaml
#import importlib # to refresh functions imported from functions.py file
#import functions # functions.function_name
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import seaborn as sns
import os

# %%
# 1. Define the PandaMonium Brand Palette
panda_colors = {
    'forest_dark': '#064e3b',    # Deepest green
    'bamboo': '#166534',         # Corporate green
    'honey': '#fbbf24',          # Highlight gold
    'slate_line': '#334155',     # Dark slate for gridlines
    'mint_bg': '#f0fdf4'         # Soft background
}

# 2. Create the Custom Colormap
panda_map = mcolors.LinearSegmentedColormap.from_list(
    'panda_strategy', [panda_colors['mint_bg'], panda_colors['bamboo'], panda_colors['forest_dark']]
)
plt.colormaps.register(cmap=panda_map)

# 3. Refined Global Styling (Fixing the Gridlines)
plt.rcParams.update({
    # Font & Figure
    'font.family': 'sans-serif',
    'figure.facecolor': 'white',
    
    # Axes & Edge styling
    'axes.facecolor': 'white',
    'axes.edgecolor': '#94a3b8',
    'axes.linewidth': 0.8,
    'axes.labelcolor': panda_colors['forest_dark'],
    'axes.titlecolor': panda_colors['forest_dark'],
    'axes.titlesize': 16,
    'axes.titleweight': 'bold',
    
    # GRIDLINE FIXES: Solid, Transparent, and Behind Data
    'axes.grid': True,
    'axes.axisbelow': True,               # Ensures grid stays behind bars/lines
    'grid.color': panda_colors['slate_line'], # Non-white color
    'grid.linestyle': '-',                # Solid lines
    'grid.alpha': 0.15,                   # High transparency (Fairly transparent)
    'grid.linewidth': 0.8,
    
    # Ticks
    'xtick.color': '#64748b',
    'ytick.color': '#64748b',
    'xtick.direction': 'out',
    'ytick.direction': 'out'
})

print("🐼 PandaMonium Visual Style Updated: Solid transparent gridlines active.")
# Out:
# 🐼 PandaMonium Visual Style Updated: Solid transparent gridlines active.

# %%
with open("../config.yaml", "r") as file:
    config = yaml.safe_load(file)

# %%
df = pd.read_csv(config['output_data']['file'])
df
# Out:
#       product_id                                       product_name  \
# 0     B014I8SSD0  Amazon Basics High-Speed HDMI Cable, 6 Feet - ...
# 1     B014I8SX4Y  Amazon Basics High-Speed HDMI Cable, 6 Feet (2...
# 2     B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# 3     B07GQD4K6L  boAt Bassheads 100 in Ear Wired Earphones with...
# 4     B07GPXXNNG  boAt Bassheads 100 in Ear Wired Earphones with...
# ...          ...                                                ...
# 1330  B0BGPN4GGH  Lifelong LLQH925 Dyno Quartz Heater 2 Power se...
# 1331  B0BL3R4RGS  VAPJA® Portable Mini Juicer Cup Blender USB Re...
# 1332  B0BNLFQDG2  Longway Blaze 2 Rod Quartz Room Heater (White,...
# 1333  B0B3JSWG81  NGI Store 2 Pieces Pet Hair Removers for Your ...
# 1334  B0BPJBTB3F  Khaitan ORFin Fan heater for Home and kitchen-...
#
#                                                category      sub_cat1  \
# 0     Electronics|HomeTheater,TV&Video|Accessories|C...   Electronics
# ...

# %% [markdown]
# #### Discounting may increase the number of reviews, which can be considered a proxy for sales

# %%
df['discount_bin'] = pd.cut(df['discount_percentage'], bins=np.arange(0, 101, 10), right=False)

result = df.groupby('discount_bin').agg(
    count=('rating', 'size'),
    mean_rating=('rating', 'mean')
).reset_index()

clean_labels = [
    '0-10%', '11-20%', '21-30%', '31-40%', '41-50%', 
    '51-60%', '61-70%', '71-80%', '80-90%', '91-100%'
]
print(result)
# Out:
#   discount_bin  count  mean_rating
# 0      [0, 10)     72     4.211111
# 1     [10, 20)     90     4.091111
# 2     [20, 30)    160     4.161250
# 3     [30, 40)    152     4.105921
# 4     [40, 50)    211     4.088626
# 5     [50, 60)    237     4.074684
# 6     [60, 70)    212     4.067925
# 7     [70, 80)    127     4.011024
# 8     [80, 90)     66     4.007576
# 9    [90, 100)      8     4.062500

# %%
# 1. Initialize the dual-axis figure
fig, ax1 = plt.subplots(figsize=(11, 6))

# Ensure discount bins are explicitly read as discrete categorical strings
result['discount_bin'] = result['discount_bin'].astype(str)

# 2. Primary Axis (ax1): Volume Count Bars
sns.barplot(
    data=result,
    x='discount_bin',
    y='count',
    ax=ax1,
    color=panda_colors['bamboo'],       # Using our core brand green
    alpha=0.85,                         # Slight opacity so it sits softly behind the trend line
    edgecolor=panda_colors['forest_dark'],
    linewidth=0.5
)

# 3. Secondary Axis (ax2): Rating Trend Line
ax2 = ax1.twinx()

ax2.plot(
    result['discount_bin'], 
    result['mean_rating'], 
    color=panda_colors['honey'],        # Highlight color for the strategic insight
    marker='o', 
    markersize=8,
    linestyle='-', 
    linewidth=3,                        # Slightly thicker to establish visual hierarchy
    label='Mean Rating',
    zorder=5                            # Keep line firmly on top of bars
)

# 4. Clean Up Gridlines & Alignments
# CRITICAL FIX: Turn off secondary grids so they don't fight with the primary ones
ax1.grid(True, axis='y', color=panda_colors['slate_line'], linestyle='-', alpha=0.15)
ax2.grid(False)

# Rotate labels on the primary axis safely
ax1.set_xticks(range(len(clean_labels)))
ax1.set_xticklabels(clean_labels, rotation=45, ha='right')
# ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')

# 5. Semantic Labeling & Coloring
ax1.set_title("The Discount Cliff: Volume vs. Consumer Sentiment", pad=20)
ax1.set_xlabel("Discount Percentage Ranges", labelpad=10)
ax1.set_ylabel("Total Product Count (Volume)", color=panda_colors['forest_dark'])
ax2.set_ylabel("Average Customer Rating", color=panda_colors['forest_dark'])

# Soften the spine colors to match the layout
for ax in [ax1, ax2]:
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_color('#cbd5e1')
    ax.spines['right'].set_color('#cbd5e1')
    ax.spines['bottom'].set_color('#cbd5e1')



# Set specific rating limits so the "Cliff" drop-off looks dramatic and clear
ax2.set_ylim(3.9, 4.3)


# Create the cross-platform relative path
output_path = os.path.join("..", "figures", "discount_rating.png")

# plt.savefig(
#     output_path,
#     dpi=300,
#     bbox_inches="tight",
#     transparent=True
# )
plt.savefig(output_path, dpi=300, bbox_inches='tight', transparent=True)
# fig.tight_layout()
plt.show()

# %% [markdown]
# ### hypothesis: correlation between product category and rating
# #### strategy:
# group by category, within each category calculate the mean,std,max,min for price
# look for a correlation between mean price and rating
# ##### caveat:
# sub categories could have major price diff: e.g. laptop vs charging cable

# %%
#look at cat 1
stats_df = df.groupby('sub_cat1').agg(
    mean_price=('actual_price', 'mean'),
    max_price=('actual_price', 'max'),
    min_price=('actual_price', 'min'),
    std_price=('actual_price', 'std'),
    count_price=('actual_price', 'count'),
    total_reviews=('rating_count', 'sum')
                
).reset_index()
rating_df = df.groupby('sub_cat1')['rating'].mean().reset_index(name='mean_rating')

# Merge stats and rating DataFrames
final_df = pd.merge(stats_df, rating_df, on='sub_cat1').round(2)
final_df[final_df.count_price >10]
# Out:
#                 sub_cat1  mean_price  max_price  min_price  std_price  \
# 1  Computers_Accessories     1859.94    59890.0       39.0    4245.96
# 2            Electronics    10272.01   139900.0      171.0   16090.20
# 5           Home_Kitchen     4162.07    75990.0       79.0    6801.70
# 7         OfficeProducts      397.19     2999.0       50.0     552.78
#
#    count_price  total_reviews  mean_rating
# 1          373        6335182         4.15
# 2          476       13938207         4.07
# 5          448        2991069         4.03
# 7           31         149675         4.31

# %%
#look at cat 2
stats_df = df.groupby('sub_cat2').agg(
    mean_price=('actual_price', 'mean'),
    max_price=('actual_price', 'max'),
    min_price=('actual_price', 'min'),
    std_price=('actual_price', 'std'),
    count_price=('actual_price', 'count'),
    total_reviews=('rating_count', 'sum')
).reset_index()
rating_df = df.groupby(['sub_cat1', 'sub_cat2'])['rating'].mean().reset_index(name='mean_rating')

# Merge stats and rating DataFrames
final_df = pd.merge(stats_df, rating_df, on='sub_cat2').round(2)
final_df[final_df.count_price >10].sort_values(['sub_cat1','count_price'], ascending=[True,False])
# Out:
#                                    sub_cat2  mean_price  max_price  min_price  \
# 1                   Accessories_Peripherals     1191.93     5499.0       39.0
# 22                        NetworkingDevices     2240.83     5499.0      349.0
# 8               ExternalDevices_DataStorage     4303.06    32000.0      450.0
# 26                Printers_Inks_Accessories     3371.91     9625.0      404.0
# 15                     HomeTheater_TV_Video    17636.34   139900.0      399.0
# 20                      Mobiles_Accessories     9943.46    74999.0      171.0
# 10           Headphones_Earbuds_Accessories     2874.32    15990.0      399.0
# 28                       WearableTechnology     7578.31    29999.0      999.0
# 3                       Cameras_Photography     2594.19     7500.0      400.0
# 12                                HomeAudio     3116.12    12499.0      600.0
# 9   GeneralPurposeBatteries_BatteryChargers      444.07     1500.0      180.0
# ...

# %%
#look at cat3, which is just the lowest level of category
sub_cat3 = df["category"].apply(
                                 lambda x : str(x).split("|")[-1]
                                            .strip()
                                            
                                            .replace(",", "_")
                                            .replace("&", "_")
                                 )
print(sub_cat3)
df.insert(5, "sub_cat3", sub_cat3)
# Out:
# 0                HDMICables
# 1                HDMICables
# 2                HDMICables
# 3                    In-Ear
# 4                    In-Ear
#                ...
# 1330        ElectricHeaters
# 1331    JuicerMixerGrinders
# 1332        ElectricHeaters
# 1333            LintShavers
# 1334             FanHeaters
# Name: category, Length: 1335, dtype: str

# %%
stats_df_end = df.groupby('sub_cat3').agg(
    mean_price=('actual_price', 'mean'),
    max_price=('actual_price', 'max'),
    min_price=('actual_price', 'min'),
    std_price=('actual_price', 'std'),
    count_price=('actual_price', 'count'),
    total_reviews=('rating_count', 'sum')
).reset_index()
rating_df_end = df.groupby(['sub_cat1', 'sub_cat2', 'sub_cat3'])['rating'].mean().reset_index(name='mean_rating')

# Merge stats and rating DataFrames
final_df_end = pd.merge(stats_df_end, rating_df_end, on='sub_cat3').round(2)
final_df_end[final_df_end.count_price >10].sort_values(['sub_cat1','count_price'], ascending=[True,False])
# Out:
#                      sub_cat3  mean_price  max_price  min_price  std_price  \
# 193                 USBCables      937.94     2100.0      199.0     500.31
# 107                      Mice     1055.79     2890.0      249.0     632.71
# 96                   Lapdesks     1945.43     4999.0      599.0    1279.19
# 208       WirelessUSBAdapters     1370.43     2999.0      349.0     800.00
# 155          ScreenProtectors     1640.67     2899.0      599.0     831.71
# 68             GraphicTablets     1320.82     4699.0      237.0    1217.03
# 174                    Stands      780.82     1499.0      499.0     426.19
# 166               Smartphones    20583.67    74999.0     7999.0   11081.94
# 164          SmartTelevisions    40974.67   139900.0    12999.0   22046.68
# 165              SmartWatches     7578.31    29999.0      999.0    4509.00
# 82                     In-Ear     2998.53    15990.0      399.0    2883.71
# ...

# %%
def clean_and_wrap(text):
    text = text.replace('_', ' ')
    if len(text) > 25:
        words = text.split(' ')
        mid = len(words) // 2
        return '\n'.join([' '.join(words[:mid]), ' '.join(words[mid:])])
    return text

final_df_end['wrapped_labels'] = final_df_end['sub_cat3'].astype(str).apply(clean_and_wrap)

# --- Thresholds: -1 std from mean ---
count_thresh = final_df_end['count_price'].mean() - final_df_end['count_price'].std()
log_reviews  = np.log(final_df_end['total_reviews'])
log_thresh   = log_reviews.mean() - log_reviews.std()
review_thresh = np.exp(log_thresh)

# --- Bubble sizes: log-scaled price ---
log_prices   = np.log(final_df_end['mean_price'])
bubble_sizes = ((log_prices - log_prices.min()) / (log_prices.max() - log_prices.min())) * 1200 + 200

# --- Opportunity flag ---
is_opp = (final_df_end['count_price'] <= count_thresh) & (final_df_end['total_reviews'] >= review_thresh)

# %%
# ── FIG 2a: niche scatter — no labels at all ─────────────────────────────────
count_thresh  = final_df_end['count_price'].median()
review_thresh = final_df_end['total_reviews'].median()

is_opp = (
    (final_df_end['count_price'] <= count_thresh) &
    (final_df_end['total_reviews'] >= review_thresh)
)

fig2, ax2 = plt.subplots(figsize=(13, 9))
fig2.patch.set_facecolor('white')

ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.scatter(
    final_df_end.loc[~is_opp, 'count_price'],
    final_df_end.loc[~is_opp, 'total_reviews'],
    s=bubble_sizes[~is_opp],
    color='#94a3b8', alpha=0.25,
    edgecolors='#64748b', linewidths=0.5, zorder=2
)

niche_ratings = final_df_end.loc[is_opp, 'mean_rating']
sc2 = ax2.scatter(
    final_df_end.loc[is_opp, 'count_price'],
    final_df_end.loc[is_opp, 'total_reviews'],
    s=bubble_sizes[is_opp],
    c=niche_ratings,
    cmap='panda_strategy',
    vmin=niche_ratings.min() - 0.05,
    vmax=niche_ratings.max() + 0.05,
    alpha=0.92,
    edgecolors=panda_colors['forest_dark'],
    linewidths=1.5, zorder=3
)

ax2.axvline(x=count_thresh,  color=panda_colors['slate_line'], linestyle='--', alpha=0.35, linewidth=0.8, zorder=1)
ax2.axhline(y=review_thresh, color=panda_colors['slate_line'], linestyle='--', alpha=0.35, linewidth=0.8, zorder=1)

y_max = final_df_end['total_reviews'].max()
ax2.fill_betweenx(
    y=[review_thresh, y_max * 2],
    x1=0.5, x2=count_thresh,
    color=panda_colors['bamboo'], alpha=0.05, zorder=0
)

ax2.text(0.6, y_max * 1.05,
         "niche zone: high demand, low competition",
         color=panda_colors['bamboo'], fontsize=10, fontweight='bold', va='top')
ax2.text(final_df_end['count_price'].max() * 0.6, y_max * 1.05,
         "competitive: stay away",
         color=panda_colors['slate_line'], fontsize=10, fontweight='bold', va='top', ha='left')
#ax2.text(0.6, review_thresh * 0.5, "low priority",
        #color='#94a3b8', fontsize=10, fontweight='bold', va='top')
ax2.text(0.6, review_thresh *0.01, "low priority",
         color=panda_colors['slate_line'], fontsize=10, fontweight='bold', va='top')

ax2.xaxis.set_major_formatter(plt.FuncFormatter(lambda v, _: str(int(v))))
ax2.yaxis.set_major_formatter(plt.FuncFormatter(
    lambda v, _: f'{int(v/1e6)}M' if v >= 1e6 else f'{int(v/1e3)}k' if v >= 1e3 else str(int(v))
))
ax2.set_xlim(0.5, final_df_end['count_price'].max() * 2)
ax2.set_ylim(final_df_end['total_reviews'].min() * 0.5, y_max * 2)
ax2.set_xlabel("Listing count (log)  →  more competition", labelpad=12)
ax2.set_ylabel("Total reviews (log)  →  higher demand", labelpad=12)

for spine in ['top', 'right']:
    ax2.spines[spine].set_visible(False)
for spine in ['left', 'bottom']:
    ax2.spines[spine].set_color('#cbd5e1')

ax2.set_title("Fig 2 — Niche candidates: high demand, low competition", pad=20)

cbar2 = plt.colorbar(sc2, ax=ax2, pad=0.02)
cbar2.set_label('Mean rating (niche candidates only)',
                color=panda_colors['forest_dark'], fontweight='bold', labelpad=10)
cbar2.ax.tick_params(colors='#64748b')

for price, label in [(500, '₹500'), (5000, '₹5k'), (20000, '₹20k')]:
    lp = np.log(price)
    s  = ((lp - log_prices.min()) / (log_prices.max() - log_prices.min())) * 1200 + 200
    ax2.scatter([], [], s=s, color='#94a3b8', alpha=0.5,
                edgecolors=panda_colors['slate_line'], linewidths=0.8, label=label)
ax2.legend(title='Bubble size = mean price', title_fontsize=9,
           fontsize=9, framealpha=0.5, loc='lower right')

plt.subplots_adjust(left=0.09, right=0.88, top=0.88, bottom=0.10)
plt.savefig(os.path.join('..', 'figures', 'fig2_niche_scatter.png'),
            dpi=300, bbox_inches='tight', transparent=True)
plt.show()


# ── FIG 3: grouped bar — sorted by composite score ───────────────────────────

niche_df = final_df_end[is_opp].copy()
niche_df['cv'] = niche_df['std_price'] / niche_df['mean_price']
niche_df = niche_df.dropna()

# Composite score: high CV is good (pricing freedom), low rating is good (quality gap)
# Normalise both 0-1 then combine — invert rating so lower = better opportunity
niche_df['rating_norm'] = 1 - (niche_df['mean_rating'] - niche_df['mean_rating'].min()) / \
                              (niche_df['mean_rating'].max() - niche_df['mean_rating'].min())
niche_df['cv_norm']     = (niche_df['cv'] - niche_df['cv'].min()) / \
                          (niche_df['cv'].max() - niche_df['cv'].min())
niche_df['score']       = (niche_df['rating_norm'] + niche_df['cv_norm']) / 2

niche_df = niche_df.sort_values('score', ascending=True)
niche_df['clean_label'] = niche_df['sub_cat3'].str.replace('_', ' ')

labels  = niche_df['clean_label'].tolist()
ratings = niche_df['mean_rating'].tolist()
cvs     = niche_df['cv'].tolist()
scores  = niche_df['score'].tolist()
x       = np.arange(len(labels))
width   = 0.38

fig3, ax3 = plt.subplots(figsize=(13, max(6, len(labels) * 0.7)))
fig3.patch.set_facecolor('white')

bars_r = ax3.barh(x + width/2, ratings, width,
                  label='Mean rating  (lower = quality gap)',
                  color=panda_colors['bamboo'],
                  alpha=0.85,
                  edgecolor=panda_colors['forest_dark'],
                  linewidth=0.5)

bars_c = ax3.barh(x - width/2, cvs, width,
                  label='Price CV  (higher = pricing freedom)',
                  color=panda_colors['honey'],
                  alpha=0.85,
                  edgecolor=panda_colors['forest_dark'],
                  linewidth=0.5)

for bar in bars_r:
    w = bar.get_width()
    ax3.text(w + 0.01, bar.get_y() + bar.get_height()/2,
             f'{w:.2f}', va='center', ha='left',
             fontsize=9, color=panda_colors['forest_dark'])

for bar in bars_c:
    w = bar.get_width()
    ax3.text(w + 0.01, bar.get_y() + bar.get_height()/2,
             f'{w:.2f}', va='center', ha='left',
             fontsize=9, color=panda_colors['forest_dark'])

ax3.axvline(x=4.2, color='#dc2626', linestyle='--', linewidth=1, alpha=0.6, zorder=1)
ax3.text(4.21, len(labels) - 0.3, '4.2 quality\nthreshold',
         color='#dc2626', fontsize=8, va='top', fontweight='bold')

# Star the top 2 by composite score
top2 = niche_df.nlargest(2, 'score')['clean_label'].tolist()
ytick_labels = []
for l in labels:
    ytick_labels.append(f'★ {l}' if l in top2 else l)

ax3.set_yticks(x)
ax3.set_yticklabels(ytick_labels, fontsize=10)

# Colour top 2 tick labels
for tick, l in zip(ax3.get_yticklabels(), labels):
    tick.set_color(panda_colors['forest_dark'] if l in top2 else '#444444')
    tick.set_fontweight('bold' if l in top2 else 'normal')

ax3.set_xlabel("Value  →", labelpad=12)
ax3.set_title("Fig 3 — Quality gap and pricing flexibility by niche candidate\n"
              "★ = best opportunity (highest combined score)", pad=20)

for spine in ['top', 'right']:
    ax3.spines[spine].set_visible(False)
for spine in ['left', 'bottom']:
    ax3.spines[spine].set_color('#cbd5e1')

ax3.legend(loc='lower right', fontsize=9, framealpha=0.5)
# ax3.text(0.98, 0.02,
#          "Sorted by opportunity score: low rating + high CV = top of chart",
#          transform=ax3.transAxes, fontsize=8,
#          color='#64748b', ha='right', va='bottom', style='italic')

plt.tight_layout()
plt.savefig(os.path.join('..', 'figures', 'fig3_niche_quality_price.png'),
            dpi=300, bbox_inches='tight', transparent=True)
plt.show()

# --- Print the top candidates clearly ---
print("\n🐼 Top niche candidates by opportunity score:")
print(niche_df[['clean_label', 'mean_rating', 'cv', 'score']]
      .sort_values('score', ascending=False)
      .to_string(index=False))
# Out:
# 🐼 Top niche candidates by opportunity score:
#            clean_label  mean_rating       cv    score
#             DustCovers         3.40 0.762666 0.904675
#              Condenser         3.90 0.680334 0.610990
# Tabletop TravelTripods         4.35 0.942318 0.525000
#               Over-Ear         4.00 0.471531 0.450197
#               Adapters         3.90 0.352896 0.437249
#            CoolingPads         4.10 0.471721 0.400298
#                Webcams         4.20 0.506387 0.368692
#              RCACables         4.30 0.319244 0.219393
#               Adapters         4.40 0.352896 0.187249
#             TripodLegs         4.05 0.000000 0.175000
#            OTGAdapters         4.25 0.005694 0.078021
